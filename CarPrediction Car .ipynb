# %% [markdown]
# # CAR PREDICTION PRICE ANALYSIS

# %%
# %pip install matplotlib
# %pip install seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings("ignore")

# %%
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = pd.read_excel("Clean_car.xlsx")

# %%
data
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 810      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 811          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 812    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 813            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 814      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [815 rows x 6 columns]

# %%
data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        815 non-null    object
#  1   company     815 non-null    object
#  2   year        815 non-null    int64
#  3   Price       815 non-null    int64
#  4   kms_driven  815 non-null    int64
#  5   fuel_type   815 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.3+ KB

# %%
data["year"].unique()
# Out:
# array([2007, 2006, 2014, 2012, 2013, 2016, 2015, 2010, 2017, 2008, 2018,
#        2011, 2019, 2009, 2005, 2000, 2003, 2004, 1995, 2002, 2001])

# %%
data['year'] = pd.to_numeric(data['year'], errors='coerce')
data = data.dropna(subset=['year'])
data['year'] = data['year'].astype('int64')

# %%
data['year'] = data['year'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        815 non-null    object
#  1   company     815 non-null    object
#  2   year        815 non-null    int64
#  3   Price       815 non-null    int64
#  4   kms_driven  815 non-null    int64
#  5   fuel_type   815 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.3+ KB

# %%
data['Price'].unique()
# Out:
# array([  80000,  425000,  325000,  575000,  175000,  190000,  830000,
#         250000,  182000,  315000,  415000,  320000, 1000000,  500000,
#         350000,  160000,  310000,   75000,  100000,  290000,   95000,
#         180000,  385000,  105000,  650000,  689999,  448000,  549000,
#         501000,  489999,  280000,  349999,  284999,  345000,  499999,
#         235000,  249999, 1475000,  395000,  220000,  170000,   85000,
#         200000,  570000,  110000,  448999, 1891111,  159500,  344999,
#         449999,  865000,  699000,  375000,  224999, 1200000,  195000,
#         351000,  240000,   90000,  155000,  600000,  189500,  210000,
#         390000,  135000, 1600000,  701000,  265000,  525000,  372000,
#         635000,  550000,  485000,  329500,  251111,  569999,   69999,
#         299999,  399999,  450000,  270000,  158400,  179000,  125000,
#         299000,  150000,  285000,  340000,   70000,  289999,  849999,
#         749999,  274999,  984999,  599999,  244999,  474999,  245000,
#         169500,  275000,  370000,  168000,  145000,   98500,  209000,
#         185000,  900000,  699999,  199999,  544999,  199000,  540000,
#          49000,  700000,   55000,  895000,  355000,  565000,  365000,
#          40000,  400000,  330000,  580000,  379000,  219000,  519000,
#         730000, 2000000, 2100000, 1400000,  311000,  855000,  535000,
#         178000,  300000,  255000,  549999,  380000,   57000,  410000,
#         225000,  120000,   59000,  599000,  675000,   72500,  610000,
#         230000,  520000,  524999,  424999,  644999,  584999,  799999,
#         444999,  649999,  944999,  574999,  374999,  130000,  401000,
#        1350000,  174999,  239999,   99999,  324999, 1074999, 1130000,
#         149000,  770000,   30000,  335000,  399000,   65000,  169999,
#         165000,  560000,  950000,  715000,   45000,  940000,  155555,
#        1500000,  495000,  800000, 1299000,  530000, 1499000,   32000,
#         405000,  760000,  750000,  419000,  140000, 1540000,  123000,
#         498000,  480000,  488000, 1525000,  548900,  725000,   99000,
#          52000, 2800000,  499000,  381000,  278000,  690000,  260000,
#          90001,  115000, 1599000,  159000,   51999,  215000,   35000,
#        1150000,  269000,   60000,  430000,  401919,  490000,  424000,
#         205000,  549900,  435000,  189700,  389700,  360000,  295000,
#         114990, 1065000,  470000,   48000,  188000,  465000,  179999,
#        2190000, 2390000, 1075000,  475000, 1025000,  615000, 1900000,
#        1490000, 1510000, 1850000,  790000, 1725000, 1225000,   68000,
#         970000, 3100000,  899000,   88000,   53000,  568500,   71000,
#         590000,  795000,   42000,  189000,  162000,   35999, 2900000,
#          39999,   50500,  510000,  860000,  500001])

# %%
data = data[data["Price"]!="Ask For Price"]

# %%
data["Price"] = pd.to_numeric(data["Price"].astype(str).str.replace(",", ""), errors="coerce")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        815 non-null    object
#  1   company     815 non-null    object
#  2   year        815 non-null    int64
#  3   Price       815 non-null    int64
#  4   kms_driven  815 non-null    int64
#  5   fuel_type   815 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.3+ KB

# %%
data['kms_driven'].unique()
# Out:
# array([ 45000,     40,  28000,  36000,  41000,  25000,  24530,  60000,
#         30000,  32000,  48660,   4000,  16934,  43000,  35550,  39522,
#         39000,  55000,  72000,  15975,  70000,  23452,  35522,  48508,
#         15487,  82000,  20000,  68000,  38000,  27000,  33000,  46000,
#         16000,  47000,  35000,  30874,  15000,  29685, 130000,  19000,
#         54000,  13000,  38200,  22000,  50000,  13500,   3600,  45863,
#         60500,  12500,  18000,  13349,  29000,  44000,  42000,  14000,
#         49000,  36200,  51000, 104000,  33333,  33600,   5600,   7500,
#         24330,  65480, 200000,  59000,  99000,   2800,  21000,  11000,
#         66000,   3000,   7000,  38500,  37200,  43200,  24800,  45872,
#         40000,  11400,  97200,  52000,  31000, 175430,  37000,  65000,
#          3350,  75000,  62000,  73000,   2200,  54870,  34580,  97000,
#            60,  80200,   3200,      0,   5000,    588,  71200, 175400,
#          9300,  56758,  10000,  56450,  56000,  32700,   9000,     73,
#        160000,  58559,  57000, 170000,  80000,   6821,  23000,  34000,
#          1800, 400000,  48000,  90000,  12000,  69900, 166000,    122,
#         36469,   7800,  24695,  15141,  59910, 100000,   4500, 129000,
#           300, 131000, 111111,  59466,  25500,  44005,   2110,  43222,
#        100200,     65, 140000, 103553,  58000, 120000,  49800,    100,
#         81876,   6020,  55700,  18500,  53000,  35500,  22134,   1000,
#          8500,  87000,   6000,   8000,  55800,  56400,  72160,  11500,
#        133000,   2000,  88000,  65422, 117000, 150000,  10750,   6800,
#          9800,  57923,  30201,   6200,  37518,  24652,    383,  95000,
#          3528,  52500,  47900,  52800, 195000,  48008,  48247,   9400,
#         64000,   2137,  10544, 147000,  90001,  48006,  74000,  85000,
#         29500,  39700,  67000,  19336,  60105,  45933, 102563,  28600,
#         41800, 116000,  42590,   7400,  54500,  76000,  11523,  38600,
#         95500,  37458,  85960,  12516,  30600,   2550,  62500,  69000,
#         28400,  68485,   3500,  85455,  63000,   1600,  77000,  26500,
#          2875,  13900,   1500,   2450,   1625,  33400,  60123, 137495,
#         91200, 146000, 100800,   2100,   2500, 132000])

# %%
data["kms_driven"] = data["kms_driven"].astype(str)\
                    .str.replace("kms", "")\
                    .str.replace(",", "")\
                    .str.strip()\
                    .astype(int)

# %%
data = data[data["kms_driven"]!="Petrol"]

# %%
data['kms_driven'] = data['kms_driven'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        815 non-null    object
#  1   company     815 non-null    object
#  2   year        815 non-null    int64
#  3   Price       815 non-null    int64
#  4   kms_driven  815 non-null    int64
#  5   fuel_type   815 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.3+ KB

# %%
data
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 810      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 811          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 812    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 813            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 814      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [815 rows x 6 columns]

# %%
data = data[~data['fuel_type'].isna()]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        815 non-null    object
#  1   company     815 non-null    object
#  2   year        815 non-null    int64
#  3   Price       815 non-null    int64
#  4   kms_driven  815 non-null    int64
#  5   fuel_type   815 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.3+ KB

# %%
data.describe()
# Out:
#               year         Price     kms_driven
# count   815.000000  8.150000e+02     815.000000
# mean   2012.442945  4.017933e+05   46277.096933
# std       4.005079  3.815888e+05   34318.459638
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.900000e+05   56879.000000
# max    2019.000000  3.100000e+06  400000.000000

# %%
data = data[data["Price"] < 6e6]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815 entries, 0 to 814
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        815 non-null    object
#  1   company     815 non-null    object
#  2   year        815 non-null    int64
#  3   Price       815 non-null    int64
#  4   kms_driven  815 non-null    int64
#  5   fuel_type   815 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 38.3+ KB

# %%
data["name"]= data["name"].str.split(" ").str.slice(0,3).str.join(' ')

# %%
data.to_excel("Clean_car.xlsx",index=False)

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
x = data.drop("Price",axis=1)
y = data["Price"]

# %%
x
# Out:
#                        name   company  year  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006          40    Diesel
# 2         Hyundai Grand i10   Hyundai  2014       28000    Petrol
# 3    Ford EcoSport Titanium      Ford  2014       36000    Diesel
# 4                 Ford Figo      Ford  2012       41000    Diesel
# ..                      ...       ...   ...         ...       ...
# 810      Maruti Suzuki Ritz    Maruti  2011       50000    Petrol
# 811          Tata Indica V2      Tata  2009       30000    Diesel
# 812    Toyota Corolla Altis    Toyota  2009      132000    Petrol
# 813            Tata Zest XM      Tata  2018       27000    Diesel
# 814      Mahindra Quanto C8  Mahindra  2013       40000    Diesel
#
# [815 rows x 5 columns]

# %%
y
# Out:
# 0       80000
# 1      425000
# 2      325000
# 3      575000
# 4      175000
#         ...
# 810    270000
# 811    110000
# 812    300000
# 813    260000
# 814    390000
# Name: Price, Length: 815, dtype: int64

# %%
ohe.fit(x[["name","company","fuel_type"]])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#         'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#         'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#         'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#         'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#         'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#         'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#         'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#         'Ford EcoSport Titanium', 'Ford EcoSport Trend',
#         'Ford Endeavor 4x4', 'Ford Fiesta', 'Ford Fiesta SXi', 'Ford Figo',
#         'Ford Figo Diesel', 'Ford Figo Duratorq', 'Ford Figo Petrol',
#         'Ford Fusion 1.4', 'Ford Ikon 1.3', 'Ford Ikon 1.6',
#         'Hindustan Motors Ambassador', 'Honda Accord', 'Honda Amaze',
#         'Honda Amaze 1.2', 'Honda Amaze 1.5', 'Honda Brio', 'Honda Brio V',
#         'Honda Brio VX', 'Honda City', 'Honda City 1.5', 'Honda City SV',
#         'Honda City VX', 'Honda City ZX', 'Honda Jazz S', 'Honda Jazz VX',
#         'Honda Mobilio', 'Honda Mobilio S', 'Honda WR V', 'Hyundai Accent',
#         'Hyundai Accent Executive', 'Hyundai Accent GLE',
#         'Hyundai Accent GLX', 'Hyundai Creta', 'Hyundai Creta 1.6',
#         'Hyundai Elantra 1.8', 'Hyundai Elantra SX', 'Hyundai Elite i20',
#         'Hyundai Eon', 'Hyundai Eon D', 'Hyundai Eon Era',
#         'Hyundai Eon Magna', 'Hyundai Eon Sportz', 'Hyundai Fluidic Verna',
#         'Hyundai Getz', 'Hyundai Getz GLE', 'Hyundai Getz Prime',
#         'Hyundai Grand i10', 'Hyundai Santro', 'Hyundai Santro AE',
#         'Hyundai Santro Xing', 'Hyundai Sonata Transform', 'Hyundai Verna',
#         'Hyundai Verna 1.4', 'Hyundai Verna 1.6', 'Hyundai Verna Fluidic',
#         'Hyundai Verna Transform', 'Hyundai Verna VGT',
#         'Hyundai Xcent Base', 'Hyundai Xcent SX', 'Hyundai i10',
#         'Hyundai i10 Era', 'Hyundai i10 Magna', 'Hyundai i10 Sportz',
#         'Hyundai i20', 'Hyundai i20 Active', 'Hyundai i20 Asta',
#         'Hyundai i20 Magna', 'Hyundai i20 Select', 'Hyundai i20 Sportz',
#         'Jaguar XE XE', 'Jaguar XF 2.2', 'Jeep Wrangler Unlimited',
#         'Land Rover Freelander', 'Mahindra Bolero DI',
#         'Mahindra Bolero Power', 'Mahindra Bolero SLE',
#         'Mahindra Jeep CL550', 'Mahindra Jeep MM', 'Mahindra KUV100',
#         'Mahindra KUV100 K8', 'Mahindra Logan', 'Mahindra Logan Diesel',
#         'Mahindra Quanto C4', 'Mahindra Quanto C8', 'Mahindra Scorpio',
#         'Mahindra Scorpio 2.6', 'Mahindra Scorpio LX',
#         'Mahindra Scorpio S10', 'Mahindra Scorpio S4',
#         'Mahindra Scorpio SLE', 'Mahindra Scorpio SLX',
#         'Mahindra Scorpio VLX', 'Mahindra Scorpio Vlx',
#         'Mahindra Scorpio W', 'Mahindra TUV300 T4', 'Mahindra TUV300 T8',
#         'Mahindra Thar CRDe', 'Mahindra XUV500', 'Mahindra XUV500 W10',
#         'Mahindra XUV500 W6', 'Mahindra XUV500 W8', 'Mahindra Xylo D2',
#         'Mahindra Xylo E4', 'Mahindra Xylo E8', 'Maruti Suzuki 800',
#         'Maruti Suzuki A', 'Maruti Suzuki Alto', 'Maruti Suzuki Baleno',
#         'Maruti Suzuki Celerio', 'Maruti Suzuki Ciaz',
#         'Maruti Suzuki Dzire', 'Maruti Suzuki Eeco',
#         'Maruti Suzuki Ertiga', 'Maruti Suzuki Esteem',
#         'Maruti Suzuki Estilo', 'Maruti Suzuki Maruti',
#         'Maruti Suzuki Omni', 'Maruti Suzuki Ritz', 'Maruti Suzuki S',
#         'Maruti Suzuki SX4', 'Maruti Suzuki Stingray',
#         'Maruti Suzuki Swift', 'Maruti Suzuki Versa',
#         'Maruti Suzuki Vitara', 'Maruti Suzuki Wagon', 'Maruti Suzuki Zen',
#         'Mercedes Benz A', 'Mercedes Benz B', 'Mercedes Benz C',
#         'Mercedes Benz GLA', 'Mini Cooper S', 'Mitsubishi Lancer 1.8',
#         'Mitsubishi Pajero Sport', 'Nissan Micra XL', 'Nissan Micra XV',
#         'Nissan Sunny', 'Nissan Sunny XL', 'Nissan Terrano XL',
#         'Nissan X Trail', 'Renault Duster', 'Renault Duster 110',
#         'Renault Duster 110PS', 'Renault Duster 85', 'Renault Duster 85PS',
#         'Renault Duster RxL', 'Renault Kwid', 'Renault Kwid 1.0',
#         'Renault Kwid RXT', 'Renault Lodgy 85', 'Renault Scala RxL',
#         'Skoda Fabia', 'Skoda Fabia 1.2L', 'Skoda Fabia Classic',
#         'Skoda Laura', 'Skoda Octavia Classic', 'Skoda Rapid Elegance',
#         'Skoda Superb 1.8', 'Skoda Yeti Ambition', 'Tata Aria Pleasure',
#         'Tata Bolt XM', 'Tata Indica', 'Tata Indica V2', 'Tata Indica eV2',
#         'Tata Indigo CS', 'Tata Indigo LS', 'Tata Indigo LX',
#         'Tata Indigo Marina', 'Tata Indigo eCS', 'Tata Manza',
#         'Tata Manza Aqua', 'Tata Manza Aura', 'Tata Manza ELAN',
#         'Tata Nano', 'Tata Nano Cx', 'Tata Nano GenX', 'Tata Nano LX',
#         'Tata Nano Lx', 'Tata Sumo Gold', 'Tata Sumo Grande',
#         'Tata Sumo Victa', 'Tata Tiago Revotorq', 'Tata Tiago Revotron',
#         'Tata Tigor Revotron', 'Tata Venture EX', 'Tata Vista Quadrajet',
#         'Tata Zest Quadrajet', 'Tata Zest XE', 'Tata Zest XM',
#         'Toyota Corolla', 'Toyota Corolla Altis', 'Toyota Corolla H2',
#         'Toyota Etios', 'Toyota Etios G', 'Toyota Etios GD',
#         'Toyota Etios Liva', 'Toyota Fortuner', 'Toyota Fortuner 3.0',
#         'Toyota Innova 2.0', 'Toyota Innova 2.5', 'Toyota Qualis',
#         'Volkswagen Jetta Comfortline', 'Volkswagen Jetta Highline',
#         'Volkswagen Passat Diesel', 'Volkswagen Polo',
#         'Volkswagen Polo Comfortline', 'Volkswagen Polo Highline',
#         'Volkswagen Polo Highline1.2L', 'Volkswagen Polo Trendline',
#         'Volkswagen Vento Comfortline', 'Volkswagen Vento Highline',
#         'Volkswagen Vento Konekt', 'Volvo S80 Summum'], dtype=object),
#  array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#         'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#         'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#         'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#        dtype=object),
#  array(['Diesel', 'LPG', 'Petrol'], dtype=object)]

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
composer = make_column_transformer((OneHotEncoder(categories=ohe.categories_),["name","company","fuel_type"]),remainder='passthrough')
LRmodel = make_pipeline(composer,LinearRegression())
RRmodel = make_pipeline(composer,RandomForestRegressor())
DTmodel = make_pipeline(composer,DecisionTreeRegressor())

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2)

# %%
LRmodel.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
pred= LRmodel.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,pred)
# Out:
# 0.6767103687128431

# %%
r2score = []
for i in range(1000):
    X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=i)
    LRmodel.fit(X_train,Y_train)
    pred=LRmodel.predict(X_test)
    r2score.append(r2_score(Y_test,pred))

# %%
np.argmax(r2score)
# Out:
# np.int64(433)

# %%
r2score[433]
# Out:
# 0.8457059012561223

# %%
from sklearn.model_selection import cross_val_score

RFr2score = cross_val_score(RRmodel, x, y, cv=10, scoring='r2')  # 10-Fold Cross Validation
print(RFr2score.mean())  # Get the average R² score
# Out:
# 0.5826783366498944

# %%
RFr2score = []
for i in range(1000):
    X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=i)
    RRmodel.fit(X_train,Y_train)
    pred=RRmodel.predict(X_test)
    RFr2score.append(r2_score(Y_test,pred))

# %%
np.argmax(RFr2score)
# Out:
# np.int64(712)

# %%
RFr2score[712]
# Out:
# 0.9144456941311956

# %%
DTr2score = []
for i in range(1000):
    X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=i)
    DTmodel.fit(X_train,Y_train)
    pred=DTmodel.predict(X_test)
    DTr2score.append(r2_score(Y_test,pred))

# %%
np.argmax(DTr2score)
# Out:
# np.int64(443)

# %%
DTr2score[712]
# Out:
# 0.8859933772984524

# %%
acc = [r2score[433],RFr2score[712],DTr2score[712]]
model = ["LR","RFR","DTR"] 
bar_label = plt.bar(model,acc,width=0.4,color=['green','red','orange'])
plt.bar_label(bar_label)
plt.xlabel("Model")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=443)
LRmodel.fit(X_train,Y_train)
pred=LRmodel.predict(X_test)
r2_score(Y_test,pred)
# Out:
# 0.8022163666838086

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=443)
RRmodel.fit(X_train,Y_train)
pred=RRmodel.predict(X_test)
r2_score(Y_test,pred)
# Out:
# 0.829574404392205

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=443)
DTmodel.fit(X_train,Y_train)
pred=DTmodel.predict(X_test)
r2_score(Y_test,pred)
# Out:
# 0.8643504012666703

# %%
# %pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\vivek\onedrive\desktop\car price\.venv\lib\site-packages (1.5.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from joblib import dump
dump(RRmodel,"RandomForestRegressor.joblib")
# Out:
# ['RandomForestRegressor.joblib']

# %%
import numpy as np
import pandas as pd
from joblib import load
model=load("RandomForestRegressor.joblib")

# %%
ohe.categories_
# Out:
# [array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#         'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#         'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#         'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#         'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#         'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#         'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#         'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#         'Ford EcoSport Titanium', 'Ford EcoSport Trend',
#         'Ford Endeavor 4x4', 'Ford Fiesta', 'Ford Fiesta SXi', 'Ford Figo',
#         'Ford Figo Diesel', 'Ford Figo Duratorq', 'Ford Figo Petrol',
#         'Ford Fusion 1.4', 'Ford Ikon 1.3', 'Ford Ikon 1.6',
#         'Hindustan Motors Ambassador', 'Honda Accord', 'Honda Amaze',
#         'Honda Amaze 1.2', 'Honda Amaze 1.5', 'Honda Brio', 'Honda Brio V',
#         'Honda Brio VX', 'Honda City', 'Honda City 1.5', 'Honda City SV',
#         'Honda City VX', 'Honda City ZX', 'Honda Jazz S', 'Honda Jazz VX',
#         'Honda Mobilio', 'Honda Mobilio S', 'Honda WR V', 'Hyundai Accent',
#         'Hyundai Accent Executive', 'Hyundai Accent GLE',
#         'Hyundai Accent GLX', 'Hyundai Creta', 'Hyundai Creta 1.6',
#         'Hyundai Elantra 1.8', 'Hyundai Elantra SX', 'Hyundai Elite i20',
#         'Hyundai Eon', 'Hyundai Eon D', 'Hyundai Eon Era',
#         'Hyundai Eon Magna', 'Hyundai Eon Sportz', 'Hyundai Fluidic Verna',
#         'Hyundai Getz', 'Hyundai Getz GLE', 'Hyundai Getz Prime',
#         'Hyundai Grand i10', 'Hyundai Santro', 'Hyundai Santro AE',
#         'Hyundai Santro Xing', 'Hyundai Sonata Transform', 'Hyundai Verna',
#         'Hyundai Verna 1.4', 'Hyundai Verna 1.6', 'Hyundai Verna Fluidic',
#         'Hyundai Verna Transform', 'Hyundai Verna VGT',
#         'Hyundai Xcent Base', 'Hyundai Xcent SX', 'Hyundai i10',
#         'Hyundai i10 Era', 'Hyundai i10 Magna', 'Hyundai i10 Sportz',
#         'Hyundai i20', 'Hyundai i20 Active', 'Hyundai i20 Asta',
#         'Hyundai i20 Magna', 'Hyundai i20 Select', 'Hyundai i20 Sportz',
#         'Jaguar XE XE', 'Jaguar XF 2.2', 'Jeep Wrangler Unlimited',
#         'Land Rover Freelander', 'Mahindra Bolero DI',
#         'Mahindra Bolero Power', 'Mahindra Bolero SLE',
#         'Mahindra Jeep CL550', 'Mahindra Jeep MM', 'Mahindra KUV100',
#         'Mahindra KUV100 K8', 'Mahindra Logan', 'Mahindra Logan Diesel',
#         'Mahindra Quanto C4', 'Mahindra Quanto C8', 'Mahindra Scorpio',
#         'Mahindra Scorpio 2.6', 'Mahindra Scorpio LX',
#         'Mahindra Scorpio S10', 'Mahindra Scorpio S4',
#         'Mahindra Scorpio SLE', 'Mahindra Scorpio SLX',
#         'Mahindra Scorpio VLX', 'Mahindra Scorpio Vlx',
#         'Mahindra Scorpio W', 'Mahindra TUV300 T4', 'Mahindra TUV300 T8',
#         'Mahindra Thar CRDe', 'Mahindra XUV500', 'Mahindra XUV500 W10',
#         'Mahindra XUV500 W6', 'Mahindra XUV500 W8', 'Mahindra Xylo D2',
#         'Mahindra Xylo E4', 'Mahindra Xylo E8', 'Maruti Suzuki 800',
#         'Maruti Suzuki A', 'Maruti Suzuki Alto', 'Maruti Suzuki Baleno',
#         'Maruti Suzuki Celerio', 'Maruti Suzuki Ciaz',
#         'Maruti Suzuki Dzire', 'Maruti Suzuki Eeco',
#         'Maruti Suzuki Ertiga', 'Maruti Suzuki Esteem',
#         'Maruti Suzuki Estilo', 'Maruti Suzuki Maruti',
#         'Maruti Suzuki Omni', 'Maruti Suzuki Ritz', 'Maruti Suzuki S',
#         'Maruti Suzuki SX4', 'Maruti Suzuki Stingray',
#         'Maruti Suzuki Swift', 'Maruti Suzuki Versa',
#         'Maruti Suzuki Vitara', 'Maruti Suzuki Wagon', 'Maruti Suzuki Zen',
#         'Mercedes Benz A', 'Mercedes Benz B', 'Mercedes Benz C',
#         'Mercedes Benz GLA', 'Mini Cooper S', 'Mitsubishi Lancer 1.8',
#         'Mitsubishi Pajero Sport', 'Nissan Micra XL', 'Nissan Micra XV',
#         'Nissan Sunny', 'Nissan Sunny XL', 'Nissan Terrano XL',
#         'Nissan X Trail', 'Renault Duster', 'Renault Duster 110',
#         'Renault Duster 110PS', 'Renault Duster 85', 'Renault Duster 85PS',
#         'Renault Duster RxL', 'Renault Kwid', 'Renault Kwid 1.0',
#         'Renault Kwid RXT', 'Renault Lodgy 85', 'Renault Scala RxL',
#         'Skoda Fabia', 'Skoda Fabia 1.2L', 'Skoda Fabia Classic',
#         'Skoda Laura', 'Skoda Octavia Classic', 'Skoda Rapid Elegance',
#         'Skoda Superb 1.8', 'Skoda Yeti Ambition', 'Tata Aria Pleasure',
#         'Tata Bolt XM', 'Tata Indica', 'Tata Indica V2', 'Tata Indica eV2',
#         'Tata Indigo CS', 'Tata Indigo LS', 'Tata Indigo LX',
#         'Tata Indigo Marina', 'Tata Indigo eCS', 'Tata Manza',
#         'Tata Manza Aqua', 'Tata Manza Aura', 'Tata Manza ELAN',
#         'Tata Nano', 'Tata Nano Cx', 'Tata Nano GenX', 'Tata Nano LX',
#         'Tata Nano Lx', 'Tata Sumo Gold', 'Tata Sumo Grande',
#         'Tata Sumo Victa', 'Tata Tiago Revotorq', 'Tata Tiago Revotron',
#         'Tata Tigor Revotron', 'Tata Venture EX', 'Tata Vista Quadrajet',
#         'Tata Zest Quadrajet', 'Tata Zest XE', 'Tata Zest XM',
#         'Toyota Corolla', 'Toyota Corolla Altis', 'Toyota Corolla H2',
#         'Toyota Etios', 'Toyota Etios G', 'Toyota Etios GD',
#         'Toyota Etios Liva', 'Toyota Fortuner', 'Toyota Fortuner 3.0',
#         'Toyota Innova 2.0', 'Toyota Innova 2.5', 'Toyota Qualis',
#         'Volkswagen Jetta Comfortline', 'Volkswagen Jetta Highline',
#         'Volkswagen Passat Diesel', 'Volkswagen Polo',
#         'Volkswagen Polo Comfortline', 'Volkswagen Polo Highline',
#         'Volkswagen Polo Highline1.2L', 'Volkswagen Polo Trendline',
#         'Volkswagen Vento Comfortline', 'Volkswagen Vento Highline',
#         'Volkswagen Vento Konekt', 'Volvo S80 Summum'], dtype=object),
#  array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#         'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#         'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#         'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#        dtype=object),
#  array(['Diesel', 'LPG', 'Petrol'], dtype=object)]

# %%
from sklearn.metrics import r2_score

accuracy = r2_score(Y_test, model.predict(X_test))
print("Model Accuracy (R² Score):", accuracy)
# Out:
# Model Accuracy (R² Score): 0.829574404392205

# %%
prediction = model.predict(pd.DataFrame({
    "name":["Audi A3 Cabriolet"],
    "company":["Audi"],
    "year":[2019],
    "kms_driven":[123000],
    "fuel_type":["Petrol"]
}))

print(prediction[0])
# Out:
# 2315430.0

# %%
prediction = model.predict(pd.DataFrame({
    "name":["BMW 3 Series"],
    "company":["BMW"],
    "year":[2021],
    "kms_driven":[12300],
    "fuel_type":["Petrol"]
}))

print(prediction[0])
# Out:
# 563399.86

# %%
prediction = model.predict(pd.DataFrame({
    "name":["BMW 3 Series"],
    "company":["BMW"],
    "year":[2020],
    "kms_driven":[123000],
    "fuel_type":["Petrol"]
}))

print(prediction[0])
# Out:
# 507359.98

# %%
prediction = model.predict(pd.DataFrame({
    "name":["BMW 7 Series"],
    "company":["BMW"],
    "year":[2020],
    "kms_driven":[123000],
    "fuel_type":["Petrol"]
}))

print(prediction[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 prediction = model.predict(pd.DataFrame({
#       2     "name":["BMW 7 Series"],
#       3     "company":["BMW"],
#       4     "year":[2020],
#       5     "kms_driven":[123000],
#       6     "fuel_type":["Petrol"]
#       7 }))
#       9 print(prediction[0])
#
# NameError: name 'model' is not defined

# %%
model=load("RandomForestRegressor.joblib")
